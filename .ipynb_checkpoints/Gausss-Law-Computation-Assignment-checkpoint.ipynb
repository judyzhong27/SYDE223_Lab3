# %% [markdown]
# **Computing Assignment #1**

# %% [markdown]
# **Please Note: I keep on getting this message "ERROR! Session/line number was not unique in database." resulting in all the electric fields strengths not to show for each time I change the value for r and x in a sphere and a cube.**

# %%
#imports
from vpython import *

# %% [markdown]
# **Exercise 1: Number of electrons**
#
# Throughout these exercises, we will simulate the motion of excess charges in a conductor for a total excess charge of Q=−5 μC. Given this value of Q, calculate the number of excess electrons in the conductor.

# %%
q = -5e-6
e = -1.602e-19

excess = q/e

print("There are",abs(excess), "excess electrons")
# Out:
# There are 31210986267166.047 excess electrons

# %% [markdown]
# ------

# %% [markdown]
# **Exercise 2: Observing the motion of N=200 charges in a conducting sphere**

# %% [markdown]
# ![title](pic1.png)

# %% [markdown]
# **What happens to the charges:**
#
# All the charges in the conducting sphere is negative (electron). As a result, according to Coulombs Law the electrons repels from one another.
#
# **Where do the charges end up:**
#
# The charges end up in a equally distrubated in lattice shape within the conductor and on the surface of the sphere.
#
# **Why does this make sense:**
#
# This makes sense because of Coulombs Law. It states that opposite charges attract and same charges repel. Since all the charges are negative they repel to form an equilibrium. This mean they move the furthest distance possible to one another, and in this case they move to the surface of the sphere and in a lattice shape within the sphere.

# %% [markdown]
# ----

# %% [markdown]
# **Exercise 3: Writing a function to compute the electric field**

# %%
#Exercise 3: Writing a function to compute the electric field
def computeEfield(P):
    global charges
    N = len(charges)
    E_net = vec(0, 0, 0)
    
    for i in range(N):
        charge_i = charges[i]
        r_i = charge_i.pos
        r_vector = P - r_i
        r = mag(r_vector)
        E = K*q/r**2 * (r_vector/r)
        E_net = E_net + E

        
    return E_net # This sends the computed value back to the main loop

# %% [markdown]
# This function calculates the electric field. Here, we are looping through each electric charge and storing its position and subtracting it from the point charge. This calculation stores the value in a vector which is the radius vector. The magnitude of the radius is found and used to calculate the electric field using the formula:
#
#                             E = (K * q)/r^2
#
# This electric field calculation is a vector and is added to the electric net field vector calculation which the net electric field of all the charges combined. We are able to do this because of the principle of superposition.

# %% [markdown]
# ----

# %% [markdown]
# **Exercise 4: Validating the E-field far from a conducting sphere: r=0.5 m, R=0.1 m**

# %%
#imports
from vpython import *

scene.width = scene.height = 600
scene.background = color.black

# Display text below the 3D graphics:
scene.title = "Charges in a Conductor"

scene.caption = """Ctrl-drag to rotate "camera" to view scene. Alt-drag to zoom.
Refresh the web page to re-execute with different (random) initial conditions."""

# Parameter values
N = 200    # Number of individual charges
Q = -5e-6  # Net charge, in Coulombs
m = 1e-3   # Mass of each charge, in kg (arbitrary)
R = 0.10   # Radius of conducting sphere, in meters
dt = 0.001 # Time step, in seconds
K = 8.99e9 # Coulomb constant

q = Q/N    # Charge for each individual charge

scene.range = 1.5*R
scene.forward = vec(-1,-1,-1)

sphere(radius = R, color=color.white, opacity = 0.5)

charges = [] # Empty array of charges, to be filled below

# Create charges with random initial positions, initially at rest:
for i in range(N):
    position = R/sqrt(3) * vec.random()
    charge = sphere(pos=position, radius = 0.01*R, color=color.red) # Random position
    charge.velocity = vec(0,0,0)   # Initially at rest
    charges.append( charge )

# Function to compute forces & update velocities
def computeForces():
    global charges
    N = len(charges)
    for i in range(N):
        charge_i = charges[i]
        F_net = vec(0,0,0)
        r_i = charge_i.pos
        for j in range(N):
            if i == j: continue # A charge doesn't interact with itself
            charge_j = charges[j]
            r_j = charge_j.pos
            r_vector = r_i - r_j
            r = mag(r_vector)
            F = K*q*q/r**2 * (r_vector/r)
            F_net = F_net + F
        a = F_net / m      # Acceleration of charge i
        if mag(a) > 1000:  # In case of a huge acceleration... 
            a = 1000 * a / mag(a) # Rescale acceleration to smaller value
        charge_i.velocity = charge_i.velocity + a*dt # Update velocity of charge i

#Exercise 3: Writing a function to compute the electric field
def computeEfield(P):
    global charges
    N = len(charges)
    E_net = vec(0, 0, 0)
    
    for i in range(N):
        charge_i = charges[i]
        r_i = charge_i.pos
        r_vector = P - r_i
        r = mag(r_vector)
        E = 1e6 * (K*q/r**2 * (r_vector/r))
        E_net = E_net + E

        
    return E_net # This sends the computed value back to the main loop
    
    
P = vec(0.5, 0, 0) # UPDATE THIS POSITION VECTOR #

graph(title='E field (uC) vs. Time (sec) with  Ex=RED,  Ey=BLUE,  Ez=GREEN')
Ex_plot = gcurve(color=color.red,   width=3) # a dataset for the plot (Ex)
Ey_plot = gcurve(color=color.blue,  width=2) # a dataset for the plot (Ey)
Ez_plot = gcurve(color=color.green, width=1) # a dataset for the plot (Ez)

t = 0 # Start the timer at t = 0

while True:
    rate(100) # Sets maximum frame rate to 100 frames per second
    
    # Compute all forces on all charges & update velocities
    computeForces()

    # Having updated all velocities, now update all positions
    for charge in charges:
        charge.pos = charge.pos + dt * charge.velocity
        d = mag(charge.pos) # Distance from center of sphere to charge
        if d > R: # If charge would have LEFT the conductor
            charge.pos = charge.pos * R / d # Bring back to edge
    
    t = t + dt                 # Update the value of time
    E_net = computeEfield(P) # After updating positions, compute E using your function
    
    # Plot each component of the E-field:
#     Ex_plot.plot(((t,  E_net.x)))
#     Ey_plot.plot(((t,  E_net.y)))
#     Ez_plot.plot(((t,  E_net.z)))
    
    # Print the numerical values of |E| in microCoulombs for each time step
    print('At P =', P, 'meters,  |E| =', mag(E_net), 'N/uC')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cef4ced464e0> in <module>
#       1 #imports
# ----> 2 from vpython import *
#       3
#       4 scene.width = scene.height = 600
#       5 scene.background = color.black
#
# ModuleNotFoundError: No module named 'vpython'

# %%
#Verify with Coulomb’s Law with a single point charge
r = 0.5

coulombs_law = 1e6 * ((K * Q) / (r) ** 2)
print("Verified with Coulomb's Law: ", abs(coulombs_law), "N/μC")
# Out:
# At P = <0.5, 0, 0> meters,  |E| = 179770645640.1529 N/uC
# Verified with Coulomb's Law:  179800000000.00003 N/μC

# %% [markdown]
# As a result, the theoretical result using Coulombs Law is consistent with the answer seen above.

# %% [markdown]
# -----

# %% [markdown]
# **Exercise 5: E-field close to a conducting sphere: r=0.15 m and R=0.10 m**

# %%
#imports
from vpython import *

scene.width = scene.height = 600
scene.background = color.black

# Display text below the 3D graphics:
scene.title = "Charges in a Conductor"

scene.caption = """Ctrl-drag to rotate "camera" to view scene. Alt-drag to zoom.
Refresh the web page to re-execute with different (random) initial conditions."""

# Parameter values
N = 200    # Number of individual charges
Q = -5e-6  # Net charge, in Coulombs
m = 1e-3   # Mass of each charge, in kg (arbitrary)
R = 0.10   # Radius of conducting sphere, in meters
dt = 0.001 # Time step, in seconds
K = 8.99e9 # Coulomb constant

q = Q/N    # Charge for each individual charge

scene.range = 1.5*R
scene.forward = vec(-1,-1,-1)

sphere(radius = R, color=color.white, opacity = 0.5)

charges = [] # Empty array of charges, to be filled below

# Create charges with random initial positions, initially at rest:
for i in range(N):
    position = R/sqrt(3) * vec.random()
    charge = sphere(pos=position, radius = 0.01*R, color=color.red) # Random position
    charge.velocity = vec(0,0,0)   # Initially at rest
    charges.append( charge )

# Function to compute forces & update velocities
def computeForces():
    global charges
    N = len(charges)
    for i in range(N):
        charge_i = charges[i]
        F_net = vec(0,0,0)
        r_i = charge_i.pos
        for j in range(N):
            if i == j: continue # A charge doesn't interact with itself
            charge_j = charges[j]
            r_j = charge_j.pos
            r_vector = r_i - r_j
            r = mag(r_vector)
            F = K*q*q/r**2 * (r_vector/r)
            F_net = F_net + F
        a = F_net / m      # Acceleration of charge i
        if mag(a) > 1000:  # In case of a huge acceleration... 
            a = 1000 * a / mag(a) # Rescale acceleration to smaller value
        charge_i.velocity = charge_i.velocity + a*dt # Update velocity of charge i

#Exercise 3: Writing a function to compute the electric field
def computeEfield(P):
    global charges
    N = len(charges)
    E_net = vec(0, 0, 0)
    
    for i in range(N):
        charge_i = charges[i]
        r_i = charge_i.pos
        r_vector = P - r_i
        r = mag(r_vector)
        E = 1e6 * (K*q/r**2 * (r_vector/r))
        E_net = E_net + E

        
    return E_net # This sends the computed value back to the main loop
    
    
P = vec(0.15 , 0, 0) # UPDATE THIS POSITION VECTOR #

graph(title='E field (uC) vs. Time (sec) with  Ex=RED,  Ey=BLUE,  Ez=GREEN')
Ex_plot = gcurve(color=color.red,   width=3) # a dataset for the plot (Ex)
Ey_plot = gcurve(color=color.blue,  width=2) # a dataset for the plot (Ey)
Ez_plot = gcurve(color=color.green, width=1) # a dataset for the plot (Ez)

t = 0 # Start the timer at t = 0

while True:
    rate(100) # Sets maximum frame rate to 100 frames per second
    
    # Compute all forces on all charges & update velocities
    computeForces()

    # Having updated all velocities, now update all positions
    for charge in charges:
        charge.pos = charge.pos + dt * charge.velocity
        d = mag(charge.pos) # Distance from center of sphere to charge
        if d > R: # If charge would have LEFT the conductor
            charge.pos = charge.pos * R / d # Bring back to edge
    
    t = t + dt                 # Update the value of time
    E_net = computeEfield(P) # After updating positions, compute E using your function
    
    # Plot each component of the E-field:
#     Ex_plot.plot(((t,  E_net.x)))
#     Ey_plot.plot(((t,  E_net.y)))
#     Ez_plot.plot(((t,  E_net.z)))
    
    # Print the numerical values of |E| in microCoulombs for each time step
    print('At P =', P, 'meters,  |E| =', mag(E_net), 'N/uC')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 220
# At P = <0.15, 0, 0> meters,  |E| = 1845763659758.6064 N/uC
# At P = <0.15, 0, 0> meters,  |E| = 1843103502076.1672 N/uC
# At P = <0.15, 0, 0> meters,  |E| = 1813398148698.144 N/uC
# At P = <0.15, 0, 0> meters,  |E| = 1882903298764.7996 N/uC
# At P = <0.15, 0, 0> meters,  |E| = 1889019576127.4978 N/uC
# At P = <0.15, 0, 0> meters,  |E| = 2024110700276.6042 N/uC
# At P = <0.15, 0, 0> meters,  |E| = 2029594159102.0322 N/uC
# At P = <0.15, 0, 0> meters,  |E| = 2009584356651.726 N/uC
# At P = <0.15, 0, 0> meters,  |E| = 2009104449121.655 N/uC

# %%
#Verify with Gauss's Law

permittivity = 8.85e-12
pi = 3.14159265359
r = 0.15
#AREA = 4 x pi x r ^ 2
A = 4 * pi * (r ** 2)

#EA = Q/permittivity
#E = Q/permittivity X A

E = 1e6 * Q/(permittivity * A)

print("Verification with Gauss's Law: ", abs(E), "N/μC")
# Out:
# Verification with Gauss's Law:  1998178820990.3936 N/μC

# %% [markdown]
# Gauss's Law is relevant because the charged is located inside a guassian surface (r > R). In other words, the surface encloses the entire charge distribution (not just the conductor). The electric field is radial, thus we can use Gauss's Law to calculate the the electric field.

# %% [markdown]
# ----

# %% [markdown]
# **Exercise 6: E-field inside of a conducting sphere: r=0.05 m and R=0.10 m**

# %%
#imports
from vpython import *

scene.width = scene.height = 600
scene.background = color.black

# Display text below the 3D graphics:
scene.title = "Charges in a Conductor"

scene.caption = """Ctrl-drag to rotate "camera" to view scene. Alt-drag to zoom.
Refresh the web page to re-execute with different (random) initial conditions."""

# Parameter values
N = 200    # Number of individual charges
Q = -5e-6  # Net charge, in Coulombs
m = 1e-3   # Mass of each charge, in kg (arbitrary)
R = 0.10   # Radius of conducting sphere, in meters
dt = 0.001 # Time step, in seconds
K = 8.99e9 # Coulomb constant

q = Q/N    # Charge for each individual charge

scene.range = 1.5*R
scene.forward = vec(-1,-1,-1)

sphere(radius = R, color=color.white, opacity = 0.5)

charges = [] # Empty array of charges, to be filled below

# Create charges with random initial positions, initially at rest:
for i in range(N):
    position = R/sqrt(3) * vec.random()
    charge = sphere(pos=position, radius = 0.01*R, color=color.red) # Random position
    charge.velocity = vec(0,0,0)   # Initially at rest
    charges.append( charge )

# Function to compute forces & update velocities
def computeForces():
    global charges
    N = len(charges)
    for i in range(N):
        charge_i = charges[i]
        F_net = vec(0,0,0)
        r_i = charge_i.pos
        for j in range(N):
            if i == j: continue # A charge doesn't interact with itself
            charge_j = charges[j]
            r_j = charge_j.pos
            r_vector = r_i - r_j
            r = mag(r_vector)
            F = K*q*q/r**2 * (r_vector/r)
            F_net = F_net + F
        a = F_net / m      # Acceleration of charge i
        if mag(a) > 1000:  # In case of a huge acceleration... 
            a = 1000 * a / mag(a) # Rescale acceleration to smaller value
        charge_i.velocity = charge_i.velocity + a*dt # Update velocity of charge i

#Exercise 3: Writing a function to compute the electric field
def computeEfield(P):
    global charges
    N = len(charges)
    E_net = vec(0, 0, 0)
    
    for i in range(N):
        charge_i = charges[i]
        r_i = charge_i.pos
        r_vector = P - r_i
        r = mag(r_vector)
        E = 1e6 * (K*q/r**2 * (r_vector/r))
        E_net = E_net + E

        
    return E_net # This sends the computed value back to the main loop
    
    
P = vec(0.05 , 0, 0) # UPDATE THIS POSITION VECTOR #

graph(title='E field (uC) vs. Time (sec) with  Ex=RED,  Ey=BLUE,  Ez=GREEN')
Ex_plot = gcurve(color=color.red,   width=3) # a dataset for the plot (Ex)
Ey_plot = gcurve(color=color.blue,  width=2) # a dataset for the plot (Ey)
Ez_plot = gcurve(color=color.green, width=1) # a dataset for the plot (Ez)

t = 0 # Start the timer at t = 0

while True:
    rate(100) # Sets maximum frame rate to 100 frames per second
    
    # Compute all forces on all charges & update velocities
    computeForces()

    # Having updated all velocities, now update all positions
    for charge in charges:
        charge.pos = charge.pos + dt * charge.velocity
        d = mag(charge.pos) # Distance from center of sphere to charge
        if d > R: # If charge would have LEFT the conductor
            charge.pos = charge.pos * R / d # Bring back to edge
    
    t = t + dt                 # Update the value of time
    E_net = computeEfield(P) # After updating positions, compute E using your function
    
    # Plot each component of the E-field:
#     Ex_plot.plot(((t,  E_net.x)))
#     Ey_plot.plot(((t,  E_net.y)))
#     Ez_plot.plot(((t,  E_net.z)))
    
    # Print the numerical values of |E| in microCoulombs for each time step
    print('At P =', P, 'meters,  |E| =', mag(E_net), 'N/uC')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 215
# At P = <0.05, 0, 0> meters,  |E| = 1440123167051.8843 N/uC
# At P = <0.05, 0, 0> meters,  |E| = 1356294355061.6646 N/uC
# At P = <0.05, 0, 0> meters,  |E| = 699700838297.7899 N/uC
# At P = <0.05, 0, 0> meters,  |E| = 386366312619.5123 N/uC

# %% [markdown]
# The E charge changes while N = 200 charges approach equilibrium is by decreasing incremently until the electric field is 0.
#
# Gauss' Law explains that the number of enclosed charges is proportional to the size of the electric field, and since the point is near the centre of the sphere, the number of enclosed charges approaches 0.
#
# In addition, r < R. In other words, the guassian surface only encloses a part of the charge distribution which is inside a conductor and it is evident that inside a conductor the electric field is 0. Therefore, there is no electric field inside the gaussian surface thus giving a electric field of 0.

# %% [markdown]
# -----

# %% [markdown]
# **Exercise 7: Observing the motion of N=8 charges in a conducting cube**

# %% [markdown]
# ![title](pic2.png)

# %% [markdown]
# **What happens to the charges:**
#
# All the charges in the conducting cube is negative (electron). As a result, according to Coulombs Law the electrons repels from one another.
#
# **Where do the charges end up:**
#
# The arrangement of the charges are at each corner of the cube
#
# **Why does this make sense:**
#
# This makes sense because of Coulombs Law. It states that opposite charges attract and same charges repel. Since all the charges are negative they repel to form an equilibrium. This mean they move the furthest distance possible to one another, and in this case they move to the vertices of the cube.

# %% [markdown]
# ---

# %% [markdown]
# **Exercise 8: Observing the motion of N=20 charges in a conducting cube**

# %% [markdown]
# ![title](pic3.png)

# %% [markdown]
# **What happens to the charges:**
#
# All the charges in the conducting cube is negative (electron). As a result, according to Coulombs Law the electrons repels from one another.
#
# **Where do the charges end up:**
#
# The arrangement of the charges are along the edges and corners of the cube. There are 8 corners and 12 edges, so each charge gets a space to be far away from the other charges.
#
# **Why does this make sense:**
#
# This makes sense because of Coulombs Law. It states that opposite charges attract and same charges repel. Since all the charges are negative they repel to form an equilibrium. This mean they move the furthest distance possible to one another, and in this case they move to the edges and corners of the cube.

# %% [markdown]
# ---

# %% [markdown]
# **Exercise 9: Observing the motion of N=200 charges in a conducting cube**

# %% [markdown]
# ![title](pic4.png)

# %% [markdown]
# **What happens to the charges:**
#
# All the charges in the conducting cube is negative (electron). As a result, according to Coulombs Law the electrons repels from one another.
#
# **Where do the charges end up:**
#
# The charges end up in a equally distrubated in lattice shape within the cube. In detail, the charges are at the corners, the edges, and they spread out among the faces of the cube.
#
# **Why does this make sense:**
#
# This makes sense because of Coloumbs Law. It states that opposite charges attract and same charges repel. Since all the charges are negative they repel to form an equilibrium. This mean they move the furthest distance possible to one another.

# %% [markdown]
# ----

# %% [markdown]
# **Exercise 10: Validating the E-field far from a conducting cube: r=0.5 m, L=0.1 m**

# %%
#imports
from vpython import *

# Charges in a conductor reaching equilibrium
# Adapted from "Stars Interacting Gravitationally" by Bruce Sherwood
scene.width = scene.height = 600
scene.background = color.black

# Display text below the 3D graphics:
scene.title = "Charges in a Rectangular Conductor"

scene.caption = """Ctrl-drag to rotate "camera" to view scene. Alt-drag to zoom.
Refresh the web page to re-execute with different (random) initial conditions."""


# Parameter values
N = 200      # Number of individual charges
Q = 5e-6   # Net charge, in Coulombs
L = 0.10   # Length of conducting cube, in meters
dt = 0.001 # Time step, in seconds
K = 8.99e9 # Coulomb constant

q = Q/N    # Charge for each individual charge

scene.range = 1.5*L
scene.forward = vec(-1,-1,-1)

box(pos=vector(0,0,0), axis=vector(1,0,0), size=vector(L,L,L), color=color.white, opacity = 0.5 )

charges = [] # Empty array of charges, to be filled below

# Create charges with random initial positions, initially at rest:
for i in range(N):
    position = L/2 * vec.random()
    charge = sphere(pos=position, radius = 0.01*L, color=color.red) # Random position
    charge.velocity = vec(0,0,0)   # Initially at rest
    charges.append(charge)

# Function to compute forces & update positions
def computeForces():
    global charges
    N = len(charges)
    for i in range(N):
        charge_i = charges[i]
        F_net = vec(0,0,0) # Will sum up force. First set to zero.
        r_i = charge_i.pos
        for j in range(N):
            if i == j: continue # A charge doesn't interact with itself
            charge_j = charges[j]
            r_j = charge_j.pos
            r_vector = r_i - r_j
            r = mag(r_vector)
            F = K*q*q/r**2 * (r_vector/r)
            F_net = F_net + F
            
        # Will use the limit of large friction, where force --> displacement
        displacement =  F_net
        if mag(displacement) > L/100:  # Don't allow a huge displacement:
            displacement = (L/100) * displacement / mag(displacement)
        
        # Update the position of the charge using the displacement above:
        charge_i.pos = charge_i.pos + displacement


# FUNCTION THAT YOU NEED TO FILL IN:
def computeEfield(P):
    global charges
    N = len(charges)
    E_net = vec(0, 0, 0)
    
    for i in range(N):
        charge_i = charges[i]
        r_i = charge_i.pos
        r_vector = P - r_i
        r = mag(r_vector)
        E = K*q/r**2 * (r_vector/r)
        E_net = E_net + E

        
    return E_net # This sends the computed value back to the main loop 


graph(title='E field (uC) vs. Time (sec) with  Ex=RED,  Ey=BLUE,  Ez=green')
Ex_plot = gcurve(color=color.red,   width=3) # a dataset for the plot (Ex)
Ey_plot = gcurve(color=color.blue,  width=2) # a dataset for the plot (Ey)
Ez_plot = gcurve(color=color.green, width=1) # a dataset for the plot (Ez)

t = 0 # Start the timer at t = 0

P = vec(0.5, 0, 0) # UPDATE THIS POSITION VECTOR #

while True:
    rate(100) # Sets maximum frame rate to 100 frames per second
    
    # Compute all forces on all charges & update positions
    computeForces()

    # Don't let the charges leave the conductor
    for charge in charges:
        
        if charge.pos.x < -L/2:
            charge.pos.x = -L/2
        if charge.pos.x > +L/2:
            charge.pos.x = +L/2
            
        if charge.pos.y < -L/2:
            charge.pos.y = -L/2
        if charge.pos.y > +L/2:
            charge.pos.y = +L/2
            
        if charge.pos.z < -L/2:
            charge.pos.z = -L/2
        if charge.pos.z > +L/2:
            charge.pos.z = +L/2
    
    t = t + dt                 # Update the value of time
    E_net = computeEfield(P) # After updating positions, compute E using your function
    
    # Plot each component of the E-field:
#     Ex_plot.plot((pos=(t,  E_net.x)))
#     Ey_plot.plot((pos=(t,  E_net.y)))
#     Ez_plot.plot((pos=(t,  E_net.z)))
    
    # Print the numerical values of |E| in microCoulombs for each time step
    print('At P =', P, 'meters,  |E| =', mag(E_net), 'N/uC')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 229
# At P = <0.5, 0, 0> meters,  |E| = 180203.22321494322 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179921.90143491616 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179783.6517841568 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.3445304679 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.77000312592 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.8133458503 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.29629880012 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.9780987563 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.7371920694 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.4681471259 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.82353281064 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.39066979245 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.60184614314 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.86927564684 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.21445397873 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.41498920202 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.98888579576 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.8131935737 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.249469267 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179731.06024384778 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179731.1080303972 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179731.20504278186 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179731.25422294595 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179731.48034519516 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179733.40057784182 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179733.78493279082 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179733.83839867575 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.63033099758 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.6105887012 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.60982650836 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.60948318464 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.60832291993 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.61048131154 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.61088619658 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.6149715224 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.64135770057 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.64501112828 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.64881769082 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.65143781487 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.6527720006 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.6684475195 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.66995819585 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.6714822736 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.6761329196 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.67770860883 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.67929670488 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.6808970099 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.68576921237 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.68741639028 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.68907479837 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.6907442439 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.69242453366 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.69411547534 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.69581687785 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.69925030533 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.70098195184 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.7027233032 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.70447417223 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.7062343734 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.70800372207 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.70978203425 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.71516892948 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.71698127876 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.71880168846 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.72062998122 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.72246598083 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.72430951244 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.72616040174 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.72988356507 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.73175549725 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.73363410393 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.73551921724 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.73741067067 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.73930829868 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.74121193745 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.74312142437 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.74503659765 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.74695729726 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.75081464072 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.75275097074 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.7546921995 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.75663817296 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.758588739 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.76054374684 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.7625030465 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.76446649007 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.76643393037 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.77038022043 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.77235878306 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.77434076855 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.7763260365 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.77831444808 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.7862968041 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.78829890056 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.79030333634 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.79230998293 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.79431871182 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.79632939684 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.7983419126 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.80035613553 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.80438921336 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.8064078277 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.85295097288 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.85900219218 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.86101657638 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.86302947442 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.86504080315 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.86705048056 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.86905842548 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.87106455813 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.87306879982 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.87507107295 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.87707130096 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.8790694088 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.8810653219 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.88305896719 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.8850502726 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.2109078783 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.2170302267 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.23953546246 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.24198548036 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.256171138 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.25432322966 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.23495625774 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.2342663424 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.23356476112 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.23285145892 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.23212638014 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.2313894694 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.2306406707 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.2298799277 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.229107184 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.22832238293 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.2275254673 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.22671637987 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.20895292622 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.20788796133 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.2068095603 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.20571766008 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.2046121976 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.20349310891 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.20236033047 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.20121379814 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.20005344762 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.19887921447 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.19769103362 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.19648884053 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.19527256946 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.0221227991 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.01934691673 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.0137327141 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.01089423758 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.00515414213 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179730.00225236692 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.99932933555 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.9963849701 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.9874230871 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.98439260447 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.98134039697 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.97826638754 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.9751704987 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.96575077684 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.96256659323 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.95936014282 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.9561313479 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.95288013204 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.94960641797 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.9463101293 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.9429911892 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.93964952114 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.9328976967 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.92948738817 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.9260540474 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.9225975991 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.9191179676 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.9156150779 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.90496610902 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.9013694378 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.8977491351 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.89410512729 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.8904373405 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.88674570154 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.88303013702 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.8755269405 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.87173916362 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.86792717132 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.86409089214 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.86023025488 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.85634518813 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.85243562123 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.84454270592 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.8405592176 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.83655094967 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.83251783325 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.82845979952 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.82437678054 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.82026870828 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.80358454707 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.79935020691 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.79509041607 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.79080510957 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.78649422302 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.78215769294 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.7734074495 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.7689936111 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.76455387945 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.76008819294 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.75559649116 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.741964697 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.7373683398 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.73274567293 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.72809663942 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.72342118286 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.71871924738 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.7092357201 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.70445401987 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.6996456244 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.69481048075 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.68505974437 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.68014404978 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.67520140533 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.67023176167 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.66021128578 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.65516036 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.6500822482 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.6449769052 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.63984428722 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.63468435113 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.6242823565 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.61904021588 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.61377059377 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.60847345102 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.59779645375 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.59241652646 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.57611061467 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.5706198242 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.56510123805 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.55955482594 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.55398055955 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.54837841092 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.53709036068 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.53140440892 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.52569047446 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.5199485349 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.50255448034 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.4967003204 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.49081806123 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.48490768753 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.4789691853 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.47300254137 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.46098478447 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.45493365207 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.44885433945 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.44274684048 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.43661114978 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.43044726373 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.42425517994 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.40550973793 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.399204866 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.39287180497 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.3865105611 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.38012114097 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.3607839226 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.35428190295 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.34775176697 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.34119353062 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.33460721216 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.32799283098 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.30798152948 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.30125512386 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.29450077648 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.2877185171 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.28090837583 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.27407038544 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.26720457966 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.2533896679 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.24644063832 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.22542775102 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.2183683371 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.21128144272 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.20416711702 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.1970254119 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.18985638063 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.18266007843 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.1754365622 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.16090812426 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.15360332592 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.14627155996 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.1389128924 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.13152739152 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.12411512743 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.11667617195 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.10171848457 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.0941999064 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.08665494388 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.07908367895 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.07148619523 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.06386257804 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.05621291537 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.04853729636 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.03310855827 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.0253556282 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.01757712022 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.00977313396 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179729.00194377106 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.99408913506 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.97037465614 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.96242000558 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.95444063094 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.9464366484 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.9384081754 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.92227824216 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.91417702805 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.90605181688 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.89790273661 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.88972991807 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.88153349375 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.85680394288 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.84851446276 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.8402020707 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.83186691217 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.82350913397 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.8151288852 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.79830158444 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.78985484107 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.78138624495 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.77289595566 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.76438413496 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.75585094662 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.74729655634 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.7387211318 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.6606244701 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.65184838048 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.6430532359 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.6342392285 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.62540655184 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.6165554021 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.60768597678 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.59879847546 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.5898930998 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.5809700526 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.5720295399 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.55409694728 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179728.52707230244 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.8785474606 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.66922460156 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.50992026975 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.50064769268 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.48214037786 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.47290613424 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.46368515992 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.44528399192 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.43610427986 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.42693880142 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.4086514912 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.3995301288 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.39042393773 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.38133314857 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.3722579898 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.3541554688 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.34512855494 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.31814784967 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179727.3091883519 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179726.32764393085 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179726.32204899334 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179726.31648077033 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179726.3109392091 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179726.30542425622 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179726.299935857 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179726.2944739562 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179726.2890384968 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179726.28362942138 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179726.2782466706 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179726.27289018544 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179726.26755990417 N/uC
# At P = <0.5, 0, 0> meters,  |E| = 179726.24129937147 N/uC

# %%
#Verify with Coulomb’s Law with a single point charge
r = 0.5

coulombs_law = 1e6 * ((K * Q) / (r) ** 2)
print("Verified with Coulomb's Law: ", abs(coulombs_law), 'N/uC')
# Out:
# Verified with Coulomb's Law:  179800000000.00003 N/uC

# %% [markdown]
# As a result, it is clear that the theoretical result of Coulombs Law stays consistent for a sphere and a cube. This makes sense because the same number of electric field lines are going through the gaussian surface.

# %% [markdown]
# -----

# %% [markdown]
# **Exercise 11: E-field close to a conducting cube: x=0.1 m and L=0.1 m**

# %%
#imports
from vpython import *

# Charges in a conductor reaching equilibrium
# Adapted from "Stars Interacting Gravitationally" by Bruce Sherwood
scene.width = scene.height = 600
scene.background = color.black

# Display text below the 3D graphics:
scene.title = "Charges in a Rectangular Conductor"

scene.caption = """Ctrl-drag to rotate "camera" to view scene. Alt-drag to zoom.
Refresh the web page to re-execute with different (random) initial conditions."""


# Parameter values
N = 200      # Number of individual charges
Q = 5e-6   # Net charge, in Coulombs
L = 0.10   # Length of conducting cube, in meters
dt = 0.001 # Time step, in seconds
K = 8.99e9 # Coulomb constant

q = Q/N    # Charge for each individual charge

scene.range = 1.5*L
scene.forward = vec(-1,-1,-1)

box(pos=vector(0,0,0), axis=vector(1,0,0), size=vector(L,L,L), color=color.white, opacity = 0.5 )

charges = [] # Empty array of charges, to be filled below

# Create charges with random initial positions, initially at rest:
for i in range(N):
    position = L/2 * vec.random()
    charge = sphere(pos=position, radius = 0.01*L, color=color.red) # Random position
    charge.velocity = vec(0,0,0)   # Initially at rest
    charges.append(charge)

# Function to compute forces & update positions
def computeForces():
    global charges
    N = len(charges)
    for i in range(N):
        charge_i = charges[i]
        F_net = vec(0,0,0) # Will sum up force. First set to zero.
        r_i = charge_i.pos
        for j in range(N):
            if i == j: continue # A charge doesn't interact with itself
            charge_j = charges[j]
            r_j = charge_j.pos
            r_vector = r_i - r_j
            r = mag(r_vector)
            F = K*q*q/r**2 * (r_vector/r)
            F_net = F_net + F
            
        # Will use the limit of large friction, where force --> displacement
        displacement =  F_net
        if mag(displacement) > L/100:  # Don't allow a huge displacement:
            displacement = (L/100) * displacement / mag(displacement)
        
        # Update the position of the charge using the displacement above:
        charge_i.pos = charge_i.pos + displacement


# FUNCTION THAT YOU NEED TO FILL IN:
def computeEfield(P):
    global charges
    N = len(charges)
    E_net = vec(0, 0, 0)
    
    for i in range(N):
        charge_i = charges[i]
        r_i = charge_i.pos
        r_vector = P - r_i
        r = mag(r_vector)
        E = K*q/r**2 * (r_vector/r)
        E_net = E_net + E

        
    return E_net # This sends the computed value back to the main loop 


graph(title='E field (uC) vs. Time (sec) with  Ex=RED,  Ey=BLUE,  Ez=green')
Ex_plot = gcurve(color=color.red,   width=3) # a dataset for the plot (Ex)
Ey_plot = gcurve(color=color.blue,  width=2) # a dataset for the plot (Ey)
Ez_plot = gcurve(color=color.green, width=1) # a dataset for the plot (Ez)

t = 0 # Start the timer at t = 0

P = vec(0.1, 0, 0) # UPDATE THIS POSITION VECTOR #

while True:
    rate(100) # Sets maximum frame rate to 100 frames per second
    
    # Compute all forces on all charges & update positions
    computeForces()

    # Don't let the charges leave the conductor
    for charge in charges:
        
        if charge.pos.x < -L/2:
            charge.pos.x = -L/2
        if charge.pos.x > +L/2:
            charge.pos.x = +L/2
            
        if charge.pos.y < -L/2:
            charge.pos.y = -L/2
        if charge.pos.y > +L/2:
            charge.pos.y = +L/2
            
        if charge.pos.z < -L/2:
            charge.pos.z = -L/2
        if charge.pos.z > +L/2:
            charge.pos.z = +L/2
    
    t = t + dt                 # Update the value of time
    E_net = computeEfield(P) # After updating positions, compute E using your function
    
    # Plot each component of the E-field:
#     Ex_plot.plot((pos=(t,  E_net.x)))
#     Ey_plot.plot((pos=(t,  E_net.y)))
#     Ez_plot.plot((pos=(t,  E_net.z)))
    
    # Print the numerical values of |E| in microCoulombs for each time step
    print('At P =', P, 'meters,  |E| =', mag(E_net), 'N/uC')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 227

# %% [markdown]
# When x == L in a cube, it means that the point is located outside of the cube. In other words, the surface encloses the entire charge distribution (not just the conductor). In that sense, we can use Gauss's Law to caculate the electric field as there are charges present outside the cube. However, since the guassian surface is a cube and has asymmetrical properties it highlights that the charges are not uniformed. This means that we cannot use Gauss's Law.

# %% [markdown]
# ------

# %% [markdown]
# **Exercise 12: E-field inside a conducting cube: x=0.01 m and L=0.1 m**

# %%
#imports
from vpython import *

# Charges in a conductor reaching equilibrium
# Adapted from "Stars Interacting Gravitationally" by Bruce Sherwood
scene.width = scene.height = 600
scene.background = color.black

# Display text below the 3D graphics:
scene.title = "Charges in a Rectangular Conductor"

scene.caption = """Ctrl-drag to rotate "camera" to view scene. Alt-drag to zoom.
Refresh the web page to re-execute with different (random) initial conditions."""


# Parameter values
N = 200      # Number of individual charges
Q = 5e-6   # Net charge, in Coulombs
L = 0.10   # Length of conducting cube, in meters
dt = 0.001 # Time step, in seconds
K = 8.99e9 # Coulomb constant

q = Q/N    # Charge for each individual charge

scene.range = 1.5*L
scene.forward = vec(-1,-1,-1)

box(pos=vector(0,0,0), axis=vector(1,0,0), size=vector(L,L,L), color=color.white, opacity = 0.5 )

charges = [] # Empty array of charges, to be filled below

# Create charges with random initial positions, initially at rest:
for i in range(N):
    position = L/2 * vec.random()
    charge = sphere(pos=position, radius = 0.01*L, color=color.red) # Random position
    charge.velocity = vec(0,0,0)   # Initially at rest
    charges.append(charge)

# Function to compute forces & update positions
def computeForces():
    global charges
    N = len(charges)
    for i in range(N):
        charge_i = charges[i]
        F_net = vec(0,0,0) # Will sum up force. First set to zero.
        r_i = charge_i.pos
        for j in range(N):
            if i == j: continue # A charge doesn't interact with itself
            charge_j = charges[j]
            r_j = charge_j.pos
            r_vector = r_i - r_j
            r = mag(r_vector)
            F = K*q*q/r**2 * (r_vector/r)
            F_net = F_net + F
            
        # Will use the limit of large friction, where force --> displacement
        displacement =  F_net
        if mag(displacement) > L/100:  # Don't allow a huge displacement:
            displacement = (L/100) * displacement / mag(displacement)
        
        # Update the position of the charge using the displacement above:
        charge_i.pos = charge_i.pos + displacement


# FUNCTION THAT YOU NEED TO FILL IN:
def computeEfield(P):
    global charges
    N = len(charges)
    E_net = vec(0, 0, 0)
    
    for i in range(N):
        charge_i = charges[i]
        r_i = charge_i.pos
        r_vector = P - r_i
        r = mag(r_vector)
        E = K*q/r**2 * (r_vector/r)
        E_net = E_net + E

        
    return E_net # This sends the computed value back to the main loop 


graph(title='E field (uC) vs. Time (sec) with  Ex=RED,  Ey=BLUE,  Ez=green')
Ex_plot = gcurve(color=color.red,   width=3) # a dataset for the plot (Ex)
Ey_plot = gcurve(color=color.blue,  width=2) # a dataset for the plot (Ey)
Ez_plot = gcurve(color=color.green, width=1) # a dataset for the plot (Ez)

t = 0 # Start the timer at t = 0

P = vec(0.01, 0, 0) # UPDATE THIS POSITION VECTOR #

while True:
    rate(100) # Sets maximum frame rate to 100 frames per second
    
    # Compute all forces on all charges & update positions
    computeForces()

    # Don't let the charges leave the conductor
    for charge in charges:
        
        if charge.pos.x < -L/2:
            charge.pos.x = -L/2
        if charge.pos.x > +L/2:
            charge.pos.x = +L/2
            
        if charge.pos.y < -L/2:
            charge.pos.y = -L/2
        if charge.pos.y > +L/2:
            charge.pos.y = +L/2
            
        if charge.pos.z < -L/2:
            charge.pos.z = -L/2
        if charge.pos.z > +L/2:
            charge.pos.z = +L/2
    
    t = t + dt                 # Update the value of time
    E_net = computeEfield(P) # After updating positions, compute E using your function
    
    # Plot each component of the E-field:
#     Ex_plot.plot((pos=(t,  E_net.x)))
#     Ey_plot.plot((pos=(t,  E_net.y)))
#     Ez_plot.plot((pos=(t,  E_net.z)))
    
    # Print the numerical values of |E| in microCoulombs for each time step
    print('At P =', P, 'meters,  |E| =', mag(E_net), 'N/uC')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 228
# At P = <0.01, 0, 0> meters,  |E| = 2261868.2918290007 N/uC

# %% [markdown]
# The E charge changes while N = 200 charges approach equilibrium is by decreasing incremently until the electric field is 0.
#
# Gauss' Law explains that the number of enclosed charges is proportional to the size of the electric field, and since the point is near the centre of the cube, the number of enclosed charges approaches 0.
#
# Also, x < L. In other words, the guassian surface only encloses a part of the charge distribution which is inside a conductor and it is evident that inside a conductor the electric field is 0. Therefore, there is no electric field inside the gaussian surface thus giving a electric field of 0.
